# %%
import gpxo
import folium
import matplotlib.pyplot as plt

# %%
track = gpxo.Track('2024-03-09_17_50_28.425_Vadodara Round.gpx')
track.map(plot='scatter', c=track.elevation, cmap='plasma')

# %%
dir(track)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_distance',
#  '_resample',
#  '_shortname_to_column',
#  'closest_to',
#  'compass',
#  'data',
#  'distance',
#  'elevation',
#  'latitude',
#  'longitude',
#  'map',
#  'plot',
#  'seconds',
#  'smooth',
#  'time',
#  'velocity']

# %%
track.data

# %%
plt.scatter(track.longitude, track.latitude, c=track.velocity)
plt.axis('off')
# Out:
# (73.15842710000001, 73.24272889999999, 22.2517007, 22.3505533)

# %%
m = folium.Map(location=[track.latitude[0], track.longitude[0]])

# %%
folium.PolyLine(
        locations=zip(track.latitude, track.longitude)
    ).add_to(m)

# %%
m
