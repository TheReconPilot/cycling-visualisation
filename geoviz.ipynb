# %% [markdown]
# # Cycling Path Visualisation

# %%
import gpxo
# import folium
import matplotlib.pyplot as plt
import os

# %%
track = gpxo.Track('2024-03-09_17_50_28.425_Vadodara Round.gpx')
# track.map()

# %%
track.data
# Out:
#                          latitude (°)  longitude (°)  distance (km)  \
# time
# 2024-03-09 17:50:33.067     22.345877      73.169191       0.000000
# 2024-03-09 17:50:35.066     22.346017      73.169284       0.018224
# 2024-03-09 17:50:39.067     22.345939      73.169215       0.029410
# 2024-03-09 17:50:41.068     22.345848      73.169210       0.039500
# 2024-03-09 17:50:43.063     22.345756      73.169181       0.050117
# ...                               ...            ...            ...
# 2024-03-09 19:30:17.084     22.345890      73.169173      32.900220
# 2024-03-09 19:30:20.068     22.346013      73.169184      32.913887
# 2024-03-09 19:30:23.069     22.346057      73.169279      32.924819
# 2024-03-09 19:30:26.074     22.346052      73.169398      32.937090
# 2024-03-09 19:30:30.061     22.346060      73.169470      32.944559
#
#                          compass (°)  duration (s)  velocity (km/h)  \
# time
# 2024-03-09 17:50:33.067    31.566601         0.000        32.819610
# 2024-03-09 17:50:35.066   305.745577         1.999        25.238494
# 2024-03-09 17:50:39.067   201.077549         6.000        15.456461
# 2024-03-09 17:50:41.068   189.579921         8.001        18.656465
# 2024-03-09 17:50:43.063   183.303868         9.996        19.481910
# ...                              ...           ...              ...
# 2024-03-09 19:30:17.084     2.878703      5984.017        18.825287
# 2024-03-09 19:30:20.068    33.989923      5987.001        14.805975
# 2024-03-09 19:30:23.069    77.991965      5990.002        13.906835
# 2024-03-09 19:30:26.074    87.875018      5993.007        11.281101
# 2024-03-09 19:30:30.061    83.149727      5996.994         6.744018
#
#                          elevation (m)
# time
# 2024-03-09 17:50:33.067          -37.1
# 2024-03-09 17:50:35.066          -21.1
# 2024-03-09 17:50:39.067          -28.2
# 2024-03-09 17:50:41.068          -35.4
# 2024-03-09 17:50:43.063          -27.8
# ...                                ...
# 2024-03-09 19:30:17.084          -16.5
# 2024-03-09 19:30:20.068          -17.6
# 2024-03-09 19:30:23.069          -19.2
# 2024-03-09 19:30:26.074          -19.8
# 2024-03-09 19:30:30.061          -19.0
#
# [2609 rows x 7 columns]

# %%
# Plot with matplotlib, colouring based on speed
plt.scatter(track.longitude, track.latitude, c=track.velocity, cmap='plasma')
plt.axis('off')
# Out:
# (73.15842710000001, 73.24272889999999, 22.2517007, 22.3505533)

# %%
# Folium Map
# m = folium.Map(location=[track.latitude[0], track.longitude[0]])

# folium.PolyLine(
#         locations=zip(track.latitude, track.longitude)
#     ).add_to(m)

# %% [markdown]
# ## All Tracks in one Plot

# %%
data_dir = "data"

# Get a list of gpx files in the data directory
track_files = [f for f in os.listdir(data_dir) if f.endswith(".gpx")]

# %%
for track_file in track_files:
    track = gpxo.Track(os.path.join(data_dir, track_file))
    
    # Plot with matplotlib, colouring based on speed
    plt.scatter(track.longitude, track.latitude, c=track.velocity, cmap='plasma')

plt.axis('off')
plt.show()
